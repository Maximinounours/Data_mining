# %% [markdown]
# ### Objectifs
#
# - Mise en place d'un [système de recommandation] (https://en.wikipedia.org/wiki/Recommender_system) bien commenté en Python
# - Rédaction du rapport de projet.
#
# ### Projet
#
#
# L'objectif de ce projet est de recommander des images en fonction des préférences
# de l'utilisateur. Vous disposez de trois séances pratiques pour construire ce système. Vous devez vous assurer que toutes les tâches liées à l'acquisition, l'annotation, l'analyse et la visualisation des données sont automatisées.
#
# Les principales tâches du projet sont présentées ci-dessous :
#
# 1.  Collecte de données
# 2.  Étiquetage et annotation
# 3.  Analyses de données
# 4.  Visualisation des données
# 5.  Système de recommandation
# 6.  Tests
# 7.  Rapport
#
# #### Collecte de données
#
# Vous devez collecter et télécharger un ensemble d'images. Vous avez les tâches suivantes à programmer, en automatisant le processus autant que possible :
#
# 1.  Créer un dossier appelé *images*.
# 2.  Télécharger les images sous licence ouverte dans le dossier *images* (minimum 100
#     images).
# 3.  Enregistrez les métadonnées de chaque image comme la taille de l'image, le format de l'image (.jpeg,
#     .png, etc.), l'orientation de l'image (paysage, portrait, carré, etc.),
#     date de création, modèle d'appareil photo, etc. dans un ou plusieurs fichiers JSON. Vous pouvez utiliser les informations [Exif](https://en.wikipedia.org/wiki/Exif) présentes dans les fichiers d'images.
#
# Pour cette tâche, vous devez rechercher les sources disposant d'informations supplémentaires
# comme les balises, les catégories, etc.
#
# #### Étiquetage et annotation
#
# Dans cette tâche, vous devrez peut-être étiqueter, annoter et enregistrer des
# des informations sur chaque image. Vous pouvez analyser les images en utilisant
# des algorithmes de regroupement pour trouver les couleurs prédominantes.
#
# Vous disposez déjà de certaines métadonnées provenant de l'EXIF des images de la précédente
# tâche. Dans cette tâche, votre objectif est d'obtenir des informations supplémentaires, comme
# les couleurs prédominantes, les tags. Et si vous demandiez aux utilisateurs de tagger les images ?
# Par exemple, les noms de couleurs, \#cat, \#fleur, \#sous-fleur, rose etc.
#
# Comment prévoyez-vous de traiter ces tags ? Est-il possible d'automatiser ce
# processus ?
#
# #### Analyses de données
#
# Demandez à l'utilisateur de sélectionner quelques images et d'ajouter des balises. Pour chaque utilisateur, vous êtes
# maintenant prêt à construire un profil de préférences d'utilisateur, basé sur cette sélection.
# Vous pouvez recueillir les informations suivantes manuellement, mais l'objectif de
# cette tâche consiste à les obtenir en utilisant les images sélectionnées de manière automatisée :
#
# 1.  Couleurs préférées
# 2.  Orientation de l'image préférée
# 3.  Tailles d'images préférées (vignettes, grandes images, images de taille moyenne
#     images, etc.)
# 4.  Balises favorites
# 5.  \...
#
# Maintenant, grâce à votre connaissance des différents types de classificateurs et
# les algorithmes de regroupement, quelles informations supplémentaires ajouterez-vous pour chaque
# image ?
#
# Votre prochain objectif est d'analyser les informations des utilisateurs et leur
# les images préférées. Comment avez-vous créé des utilisateurs aléatoires ? Combien d'utilisateurs avez-vous
# créer ? Quelles informations avez-vous stockées pour chaque utilisateur ? Quels types d'analyses avez-vous effectuées ?
#
# #### Visualisation des données
#
# Dans cette tâche, votre objectif est de visualiser les différentes caractéristiques de
# toutes les images téléchargées.
#
# 1.  Le nombre d'images disponibles pour chaque année
# 2.  Le nombre d'images disponibles pour les différents types : taille de l'image,
#     l'orientation des images, les modèles d'appareils photo, etc.
# 3.  Caractéristiques des couleurs
#
# Les utilisateurs peuvent également visualiser les informations ci-dessus relatives à leurs images préférées. Dans cette tâche, vous devez également ajouter une fonctionnalité permettant aux utilisateurs de visualiser les informations liées à leur propre profil d'utilisateur.
#
# #### Système de recommandation
#
# Êtes-vous maintenant prêt à recommander des images à un utilisateur ? Dans cette tâche, votre objectif est de construire le système de recommandation. Quelle approche avez-vous décidé de prendre ? Filtrage collaboratif, basé sur le contenu ou une approche hybride ? Pour chaque utilisateur, êtes-vous maintenant en mesure de construire une profil ? Quel type d'information avez-vous utilisé pour établir un profil d'utilisateur profil ? Qu'est-ce qui manque ? Quelles sont les limites de votre proposition ?
#
# #### Tests
#
# Votre prochaine tâche consiste à mettre au point et à effectuer différents tests sur votre proposition système. Les différentes fonctions sont-elles fonctionnelles ? Comment avez-vous testé votre projet ? Comment vérifiez-vous que votre système de recommandation fonctionne ?
#
# #### Rapport
#
# Votre tâche finale consiste à préparer un rapport de 4 pages sur le projet (en français ou en anglais).
# anglais) en format PDF, qui détaille les points suivants :
#
# - Le but de votre projet
# - Sources des données de vos images et leur licence.
# - Taille de vos données.
# - Informations que vous avez décidé de stocker pour chaque image.
# - Informations concernant les préférences de l'utilisateur
# - Les modèles d'exploration de données et/ou d'apprentissage machine que vous avez utilisés avec les métriques obtenues.
# - l'auto-évaluation de votre travail.
# - Remarques concernant les séances pratiques, les exercices et les possibilités d'amélioration.
# - Conclusion
#
# **Note** : Veuillez n'ajouter aucun programme (ou code) dans ce rapport.
#
# ### Soumission
#
#
# - Veuillez **ne pas** soumettre vos images.
# - Renommez votre rapport de projet sous le nom de Nom1\_Nom2\_\[Nom3\].pdf, où Nom1, Nom2, etc. sont vos noms.
# - Ajoutez votre rapport de projet dans votre dossier de projet.
# - Compressez et renommez votre travail de projet comme Nom1\_Nom2\_\[Nom3\].zip, où Nom1, Nom2 sont vos noms.
# - Soumettez votre **projet** en ligne.
#
# ### Évaluation
#
#
# Les critères d'évaluation des projets sont indiqués ci-dessous :
#
# 1.  Collecte de données
#     1. Approches automatisées de la collecte de données
#     2. Utilisation d'images sous licence libre
#     3. Stockage et gestion des images et des métadonnées associées
# 2.  Étiquetage et annotation
#     1. Approches automatisées de l'étiquetage
#     2. Stockage et gestion des étiquettes et des annotations des images
#     3. Utilisation d'algorithmes de classification et de regroupement
# 3.  Analyses de données
#     1. Types d'analyses utilisées
#     2. Utilisation de Pandas et Scikit-learn
#     3. Utilisation d'algorithmes d'exploration de données
# 4.  Visualisation des données
#     1. Types de techniques de visualisation utilisées
#     2. Utilisation de matplotlib
# 5.  Système de recommandation
#     1. Stockage et gestion des préférences et du profil de l'utilisateur
#     2. Utilisation d'algorithmes de recommandation
# 6.  Tests
#     1. Présence de tests fonctionnels
#     2. Présence de tests utilisateurs
# 7.  Rapport
#     1. Clarté de la présentation
#     2. Présence d'une introduction et d'une conclusion claires, architecture
#         des diagrammes, un résumé des différentes tâches réalisées et des limites
#     3. Bibliographie

# %%
#Recuperer des images
#Sauvegarder les images
#Recuperer les dimensions et l'orientation
#Recuperer les 2 couleurs dominantes


#HTML
#Recuperer des tags pour nos images
#Recuperer la date de prise de l'image


#Faire choisir 4-5 images a l'utilisateur
#Selon les choix, etiquetter les images de la base de donnee avec fav/no fav


#Visualiser les données :
    #Nombre d'image par nb de pixels
    #nb d'image par dimensions
    #nb d'images par annees
    #nb d'images par categorie
    #nb d'images par couleur dominante
    
    
#tags : width, height, format, date, couleur, extension, categorie.

# %%
# ========= IMPORTS =========

import urllib.request
import json
import pandas as pd
import requests
from PIL import Image
from PIL.ExifTags import TAGS
from bs4 import BeautifulSoup
import random
import IPython.display as display
import matplotlib.pyplot as plot

import os
import shutil


import numpy
from sklearn.cluster import MiniBatchKMeans
import math
import time

LIMIT_IMG_CAT = 10

# %%
# ========= CLASS UTILISATEUR =========

class Utilisateur:
    def __init__(self, id):
        if BDD_USER_PROJET.get(id) is None:
            self.id = id
            self.avis = {}
            BDD_USER_PROJET[id] = self
        else:
            return None
        
        
    def add_avis(self, like, id):
        #like = True ou False (dislike)
        self.avis[id] = like

# %%
# ========= Créer les répertoires et fichiers utiles =========
try:
   os.mkdir('./images')
except:
    shutil.rmtree('./images')
    os.mkdir('./images')

open('./BDD_DATA_PROJET.json', 'w').close()

# %%
# ========= Differentes categories d'images =========

categorie = ["https://commons.wikimedia.org/wiki/Category:Quality_images_of_Acinonyx_jubatus",
             "https://commons.wikimedia.org/wiki/Category:Quality_images_of_Bison_bison",
             "https://commons.wikimedia.org/wiki/Category:Quality_images_of_Kobus_kob",
             "https://commons.wikimedia.org/wiki/Category:Quality_images_of_cats",
             "https://commons.wikimedia.org/wiki/Category:Quality_images_of_Panthera_uncia",
             "https://commons.wikimedia.org/wiki/Category:Featured_pictures_of_Accipitriformes",
             "https://commons.wikimedia.org/wiki/Category:Featured_pictures_of_Haliaeetus",
             "https://commons.wikimedia.org/wiki/Category:Featured_pictures_of_Anseriformes"
            ]

# %%
#Notre BDD
BDD_DATA_PROJET = {}
BDD_USER_PROJET = {}
BDD_TAGS_PROJET = {}

# %%
# ========= LES FONCTIONS =========


#Telecharge l'image dont le lien est ids i save == True
#Sauvegarde le chemin relatif vers cette image
def save_image(id, save):
    #save : pour enregistrer l'image ou non (mettre False si l'image est deja telechargee)
    
    #Nom de notre image dans le dossier images
    nom_image = id.split("/")[-1]
    #Recupere la page html de l'image et ses donnees
    req = requests.get(id)
    soup = BeautifulSoup(req.text, 'html.parser')
    #Recupere le lien vers l'image a telecharger
    lien_image = soup.find('div', {'id' : 'file'}).find('img').attrs['src']
    #Permet de sauvegarder une image dans nos donees locales si voulu
    if save:
      f = open("./images/" + nom_image,'wb')
      f.write(requests.get(lien_image).content)
      f.close()
    
    #Ajoute le tag nom_image dans noter base de doneee
    add_data_tag(id, 'nom_image',"./images/" + nom_image)


#Ajoute une entree dans notre base de donnee pour une image
def add_data(id):
    BDD_DATA_PROJET[id] = {}

#Ajoute pour l'image id une association tag/valeur, valeur est un string
#l'id de notre base de donnee est le lien vers la page web de l'image
def add_data_tag(id, tag, valeur):
    if BDD_DATA_PROJET.get(id) is None:
        BDD_DATA_PROJET[id] = {tag : valeur}
    else:
        BDD_DATA_PROJET[id][tag] = valeur
        
    #Ajoute le tag dans le dictionnaire de tags, et la valeur correspondante
    if BDD_TAGS_PROJET.get(tag) is None:
        BDD_TAGS_PROJET[tag] = [valeur]
    elif valeur not in BDD_TAGS_PROJET[tag]:
        BDD_TAGS_PROJET[tag].append(valeur)
        
#Ecrit la BDD BDD_DATA_PROJET dans le fichier JSON
def ecriture_json():
    with open('./BDD_DATA_PROJET.json', 'w') as fichier:
        json.dump(BDD_DATA_PROJET, fichier)

#Retire une entree de la BDD (pas du fichier JSON)
def remove_data(id):
    BDD_DATA_PROJET.pop(id)
    #ecriture_json()

def get_orientation(width, height):
    format_image = "paysage"
    if width == -1 or height == -1:
        return "-1"
    if(width < height):
        format_image = "portrait"
    elif width == height:
        format_image = "carre"
    return format_image


def get_exif_field (exif,field) :
  for (clef,valeur) in exif.items():
     if ExifTags.TAGS.get(clef) == field:
        return valeur
    
    
#Construction d'une liste de couleur complet avec 27 (n³) couleurs différentes
DICT_COULEURS = []
val = [0,128,255]
for i in val:
    for j in val:
        for k in val:
            DICT_COULEURS.append(get_hex_code([i,j,k]))

#Recuperer le code hexa #RRGGBB a partir des valeurs de R, G, et B
def get_hex_code(code):
    R, G, B = code
    R = "0" + str(hex(R)[2:4]) if (R<16) else str(hex(R)[2:4])
    G = "0" + str(hex(G)[2:4]) if (G<16) else str(hex(G)[2:4])
    B = "0" + str(hex(B)[2:4]) if (B<16) else str(hex(B)[2:4])
    return "#" + R + G + B

#Recuperer les valeurs R, G, et B à partir du code hexa #RRGGBB
def get_RGB(code):
    return [int(code[1:3], 16), int(code[3:5],16), int(code[5:7],16)]

#Arrondir un code couleur en un autre de la liste
def arrondir_couleur(code):
    #code de la forme #RRGGBB en hexa
    print(code)
    R, G, B = get_RGB(code)
    distance = 1000
    couleur = []
    for r in DICT_COULEURS:
        r = get_RGB(r)
        if distance > abs(R - r[0]) + abs(G - r[1]) + abs(B - r[2]):
            distance = abs(R - r[0]) + abs(G - r[1]) + abs(B - r[2])
            couleur = r
    return get_hex_code(couleur)

# %%
# ========= Beautiful Soup, recuperation des images =========


#Faire une boucle for dans les differentes categories
for i in categorie:
    lien = i
    req = requests.get(lien)
    soup = BeautifulSoup(req.text, 'html.parser')

    #Recup tous les liens des images (id dans notre BDD)
    MAX_IMG = len(soup.find('div', {'id':'mw-category-media'}).find_all('img'))
    nb_img = 0

    #On parcourt les images du div contenant les contenant toutes
    #Valable uniquement pour les pages "Category:" sur Wikispecies
    for a in soup.find('div', {'id':'mw-category-media'}).find_all('img'):

        #Limite a LIMIT_IMG_CAT images par categorie
        if nb_img == LIMIT_IMG_CAT or nb_img == MAX_IMG:
            break

        #Lien partiel vers l'image
        a = a.find_parent('a').attrs['href']

        #Recup extension de l'image
        b = a.split(".")[-1]

        #On ne garde que .png ou .jpg
        if (b=="png" or b=="jpg"):

            #Compteur pour ne pas en avoir trop
            nb_img += 1

            #Lien complet vers la page de l'image
            lien = 'https://commons.wikimedia.org'+ a

            #Ajoute dans notre base de donnee une entree pour le l'image trouvee
            add_data(lien)

#Ecriture dans le fichier JSON
ecriture_json()

# %%
#Ajout des tags dans le dictionnaire
for lienImg in BDD_DATA_PROJET:
    
    reqImg = requests.get(lienImg)
    soup = BeautifulSoup(reqImg.text, 'html.parser')
    summary=soup.find('div', {'id' : 'mw-imagepage-content'})
    image=soup.find('div', {'id' : 'file'}).find('img')
    try:
        date=int(summary.find('time',{'class':'dtstart'}).attrs['datetime'].split('-')[0])
    except: 
        date=-1
    
    try:
        height=100*round(int(image.attrs['data-file-height'])/100,0)
    except: 
        height=-1
        
    try:
        width=100*round(int(image.attrs['data-file-width'])/100, 0)
    except: 
        width=-1
        
    try:
        extension=soup.find("span", class_="mime-type").get_text().split('/')[1]
    except: 
        extension="-1"
        
    tags=[]
    for category in soup.findAll('div', {'id' : 'mw-normal-catlinks'})[0].findChildren("a")[1:]:
        tags.append(category.attrs['title'].split(':')[1]) 
        
    add_data_tag(lienImg, 'date', int(date))
    add_data_tag(lienImg, 'width', width)
    add_data_tag(lienImg, 'orientation', get_orientation(width,height))
    add_data_tag(lienImg, 'height', height)
    add_data_tag(lienImg, 'extension', extension)
    add_data_tag(lienImg, 'categorie', tags[0].split(" ")[0])
#Ecriture dans le fichier JSON
ecriture_json()

# %%
# ========= Sauvegarde les images =========

for id in BDD_DATA_PROJET:
    time.sleep(0.1)
    save_image(id, True)
    
ecriture_json()

# %%
# ========= Recuperer les couleurs dominantes de notre image =========

n = 4 #clusters Kmeans

cpt = 0

for id in BDD_DATA_PROJET:
    #1 a 2s par image

    #start = time.time()
    
    #Erreur potentielle d'ouverture de l'image
    try:
        IMG = Image.open(BDD_DATA_PROJET[id]['nom_image'])
    except:
        add_data_tag(id, 'color1', None)
        add_data_tag(id, 'color2', None)
        continue

    #Lecture des données EXIF
    img_exif = IMG.getexif()
    
    #Check s'il y a des donnees exif
    if img_exif is None:
        add_data_tag(id, 'color1', None)
        add_data_tag(id, 'color2', None)
        continue

    #Check s'il y a 3 canaux de couleur (image en couleur)
    if len(IMG.getbands()) != 1:

        #Couleurs predominantes avec Kmeans
        numarray = numpy.array(IMG.getdata(), numpy.uint8)

        color = []
        cluster_count = 5 

        clusters = MiniBatchKMeans(n_clusters = cluster_count)
        clusters.fit(numarray)

        npbins = numpy.arange(0, cluster_count + 1)
        histogram = numpy.histogram(clusters.labels_, bins=npbins)
        labels = numpy.unique(clusters.labels_)

        for nbr in range(cluster_count):
            color.append('#%02x%02x%02x' % (
            math.ceil(clusters.cluster_centers_[nbr][0]), 
                math.ceil(clusters.cluster_centers_[nbr][1]),
          math.ceil(clusters.cluster_centers_[nbr][2])))
        
        #Recup les couleurs dominantes
        color1 = arrondir_couleur(color[0])
    
    #Si image en N&B
    else:
        color1 = '#ffffff'
        color2 = '#000000'

    add_data_tag(id, 'color1', color1)
    
    #end = time.time()
    #print(end - start)
    
ecriture_json()
# Out:
# #948462
# 148 132 98
# #5b5431
# 91 84 49
# #43361e
# 67 54 30
# #60562f
# 96 86 47
# #7c682c
# 124 104 44
# #868351
# 134 131 81
# #5e4f3e
# 94 79 62
# #2b271a
# 43 39 26
# #d5a067
# 213 160 103
# #765d3b
# 118 93 59
# #745c35
# 116 92 53
# #f7eee3
# 247 238 227
# #2c2420
# 44 36 32
# #a2a75f
# 162 167 95
# #10190c
# 16 25 12
# #121314
# 18 19 20
# #3e2814
# 62 40 20
# #657545
# 101 117 69
# #e6bd90
# 230 189 144
# #b2b090
# 178 176 144
# #b2987f
# 178 152 127
# #adb37d
# 173 179 125
# #ddb586
# 221 181 134
# #afbc88
# 175 188 136
# #bd9563
# 189 149 99
# #a7aeb1
# 167 174 177
# #b9bfc1
# 185 191 193
# #534a3d
# 83 74 61
# #6f8132
# 111 129 50
# #44241e
# 68 36 30
# #d5cfce
# 213 207 206
# #353839
# 53 56 57
# #6e725f
# 110 114 95
# #ab7f4f
# 171 127 79
# #5d432f
# 93 67 47
# #615950
# 97 89 80
# #5b534b
# 91 83 75
# #525350
# 82 83 80
# #59524a
# 89 82 74
# #93af72
# 147 175 114
# #6f874a
# 111 135 74
# #cecda7
# 206 205 167
# #181616
# 24 22 22
# #8ba5bf
# 139 165 191
# #405017
# ...

# %%
id='sophie'
BDD_USER_PROJET = {}
user=Utilisateur(id)
user = BDD_USER_PROJET[id]
for i in range(50):
    i += 1
    randomKey = random.choice(list(BDD_DATA_PROJET.keys())) 
    rep = random.randint(0,1)  
    if rep == 1:
        user.add_avis(True,randomKey)
    else:
        user.add_avis(False,randomKey)

# %%
DATAFRAME_DATA = pd.DataFrame(BDD_DATA_PROJET)
#Colonne = tag
#Ligne = id
DATAFRAME_DATA = DATAFRAME_DATA.transpose()

fig, axes = plot.subplots(nrows=3, ncols=2, figsize=(20,25))
fig.suptitle('Data base visualization', size = 40)


# === By height ===
parHauteur = DATAFRAME_DATA.groupby(by = 'height').size().reset_index(name='count')
height = parHauteur['height']
nb = parHauteur['count']

axes[0,0].bar(height, nb, width = 80.0)
axes[0,0].set_title('Nb of images by height', size = 20)

# === By width ===
parLargeur = DATAFRAME_DATA.groupby(by = 'width').size().reset_index(name='count')
width = parLargeur['width']
nb = parLargeur['count']
axes[0,1].bar(width, nb, width = 80.0)
axes[0,1].set_title('Nb of images by width', size = 20)

# === By amain color ===
parCouleur = DATAFRAME_DATA.groupby(by = 'color1').size().reset_index(name='count')
couleurs = parCouleur['color1']
nb = parCouleur['count']
bar = axes[1,0].bar(couleurs, nb)
axes[1,0].set_title('Nb of images by main color', size = 20)
for i in range(len(couleurs)):
    bar[i].set_color(couleurs[i])

plot.sca(axes[1, 0])
plot.xticks(rotation = 90)

# === By date ===
#On retire les données sans date (date = -1 dans ce cas)
df_date = DATAFRAME_DATA[DATAFRAME_DATA.date != -1]

parDate = df_date.groupby(by = 'date').size().reset_index(name='count')
dates = parDate['date']
nb = parDate['count']
axes[1,1].bar(dates, nb)
axes[1,1].set_title('Nb of images by date', size = 20)


# === By category ===
parCategorie = DATAFRAME_DATA.groupby(by = 'categorie').size().reset_index(name='count')
category = parCategorie['categorie']
nb = parCategorie['count']
axes[2,0].bar(category, nb)
axes[2,0].set_title('Nb of images by category', size = 20)
plot.sca(axes[2, 0])
plot.xticks(rotation = 90)

fig.tight_layout()
fig.subplots_adjust(top=0.92)
plot.show()

# %%
test = pd.DataFrame([len(i) for i in BDD_TAGS_PROJET.values()], [list(BDD_TAGS_PROJET.keys())])
test
# Out:
#               0
# date         15
# width        38
# orientation   3
# height       27
# extension     1
# categorie    32
# nom_image    71
# color1       10

# %%
from sklearn import datasets, metrics
from sklearn.linear_model import Perceptron
import numpy as np
import matplotlib.pyplot as plot
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import LabelEncoder


tags_recommendation = ['date', 'width', 'orientation', 'height', 'extension', 'categorie', 'color1']

ENCODEURS = []
le_result = LabelEncoder()
le_result.fit_transform(['True', 'False'])
ENCODEUR_RESULT = le_result
#Creation de label et encodeur numeriques
for key in tags_recommendation:
    le = LabelEncoder()
    le.fit(list(BDD_TAGS_PROJET.get(key)))
    ENCODEURS.append(le)
    
    
    
training_keys = list(user.avis.keys())

#Liste de liste, chaque sous-liste contient les tags de na n-eme image de training
training_tags = []

for key in training_keys:
    
    #Liste des tags pour l'image consideree
    ma_liste = []
    
    #Recupere date, width, orientation, height, extension, category, couleur principale
    for key_tag in range(len(tags_recommendation)):
        
        #Recupere la valeur du tag
        tag = BDD_DATA_PROJET[key].get(tags_recommendation[key_tag])
        
        #Encode cette valeur
        tag = ENCODEURS[key_tag].transform([tag])
        
        #Ajoute a notre liste
        ma_liste.append(tag[0])
    
    #Ajoute tous les tags encodes de l'image
    training_tags.append(ma_liste)

#Les attentes du classificateur (Like:True / Dislike:False)
training_target = ENCODEUR_RESULT.fit_transform(list(user.avis.values()))


bug = True
while bug == True:


    #max_iter a changer
    classifier = MLPClassifier(alpha=3, max_iter=2000) 

    #training
    for i in range(len(training_keys)):
        training_data = np.array(training_tags[i])
        training_data = training_data.reshape(1, -1)

        classifier.partial_fit(
            training_data,
            [training_target[i]],
            classes=np.unique(training_target)
        )

    #prediction

    images_showed = {}
    nb_prediction = 0
    trials = 0
    #bug si on ne tombe pas sur une image aimee dans les 15 premieres
    while (nb_prediction < 5) and (trials < 15 or bug == False):
        
        trials += 1
        
        time.sleep(0.1)
        random.seed(time.time())

        predict_tags = []
        randomKey = random.choice(list(BDD_DATA_PROJET.keys())) 
        
        if (randomKey in training_keys) or (randomKey in images_showed.keys()):
            continue

        tags = list(BDD_DATA_PROJET[randomKey].values())
        predict_tags = []

        #Recupere date, width, orientation, height, extension, category, couleur principale
        for key_tag in range(len(tags_recommendation)):

            #Recupere la valeur du tag
            tag = BDD_DATA_PROJET[key].get(tags_recommendation[key_tag])

            #Encode cette valeur
            tag = ENCODEURS[key_tag].transform([tag])

            #Ajoute a notre liste
            predict_tags.append(tag[0])

        predicted_labels = classifier.predict(np.array(predict_tags).reshape(1, -1))

        if predicted_labels[0] == 1:
            images_showed[randomKey] = BDD_DATA_PROJET[randomKey]
            display.display(Image.open(BDD_DATA_PROJET.get(randomKey).get('nom_image')))
            nb_prediction += 1
            bug = False
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x459 at 0x7F5DC88536A0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=410x600 at 0x7F5DC88534E0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=445x599 at 0x7F5DC8853C18>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x533 at 0x7F5DC88536A0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=398x599 at 0x7F5DC88534E0>

# %%
images_liked = {}

for id in user.avis:
    if user.avis[id] == True:
        images_liked[id] = BDD_DATA_PROJET[id]

DATAFRAME_DATA = pd.DataFrame(images_liked)
#Colonne = tag
#Ligne = id
DATAFRAME_DATA = DATAFRAME_DATA.transpose()

fig, axes = plot.subplots(nrows=3, ncols=2, figsize=(20,25))
fig.suptitle('Data base visualization', size = 40)


# === By height ===
parHauteur = DATAFRAME_DATA.groupby(by = 'height').size().reset_index(name='count')
height = parHauteur['height']
nb = parHauteur['count']

axes[0,0].bar(height, nb, width = 80.0)
axes[0,0].set_title('Nb of images by height', size = 20)

# === By width ===
parLargeur = DATAFRAME_DATA.groupby(by = 'width').size().reset_index(name='count')
width = parLargeur['width']
nb = parLargeur['count']
axes[0,1].bar(width, nb, width = 80.0)
axes[0,1].set_title('Nb of images by width', size = 20)

# === By amain color ===
parCouleur = DATAFRAME_DATA.groupby(by = 'color1').size().reset_index(name='count')
couleurs = parCouleur['color1']
nb = parCouleur['count']
bar = axes[1,0].bar(couleurs, nb)
axes[1,0].set_title('Nb of images by main color', size = 20)
for i in range(len(couleurs)):
    bar[i].set_color(couleurs[i])

plot.sca(axes[1, 0])
plot.xticks(rotation = 90)

# === By date ===
#On retire les données sans date (date = -1 dans ce cas)
df_date = DATAFRAME_DATA[DATAFRAME_DATA.date != -1]

parDate = df_date.groupby(by = 'date').size().reset_index(name='count')
dates = parDate['date']
nb = parDate['count']
axes[1,1].bar(dates, nb)
axes[1,1].set_title('Nb of images by date', size = 20)


# === By category ===
parCategorie = DATAFRAME_DATA.groupby(by = 'categorie').size().reset_index(name='count')
category = parCategorie['categorie']
nb = parCategorie['count']
axes[2,0].bar(category, nb)
axes[2,0].set_title('Nb of images by category', size = 20)
plot.sca(axes[2, 0])
plot.xticks(rotation = 90)

fig.tight_layout()
fig.subplots_adjust(top=0.92)
plot.show()

# %%
DATAFRAME_DATA = pd.DataFrame(images_showed)
#Colonne = tag
#Ligne = id
DATAFRAME_DATA = DATAFRAME_DATA.transpose()

fig, axes = plot.subplots(nrows=3, ncols=2, figsize=(20,25))
fig.suptitle('Data base visualization', size = 40)


# === By height ===
parHauteur = DATAFRAME_DATA.groupby(by = 'height').size().reset_index(name='count')
height = parHauteur['height']
nb = parHauteur['count']

axes[0,0].bar(height, nb, width = 80.0)
axes[0,0].set_title('Nb of images by height', size = 20)

# === By width ===
parLargeur = DATAFRAME_DATA.groupby(by = 'width').size().reset_index(name='count')
width = parLargeur['width']
nb = parLargeur['count']
axes[0,1].bar(width, nb, width = 80.0)
axes[0,1].set_title('Nb of images by width', size = 20)

# === By amain color ===
parCouleur = DATAFRAME_DATA.groupby(by = 'color1').size().reset_index(name='count')
couleurs = parCouleur['color1']
nb = parCouleur['count']
bar = axes[1,0].bar(couleurs, nb)
axes[1,0].set_title('Nb of images by main color', size = 20)
for i in range(len(couleurs)):
    bar[i].set_color(couleurs[i])

plot.sca(axes[1, 0])
plot.xticks(rotation = 90)

# === By date ===
#On retire les données sans date (date = -1 dans ce cas)
df_date = DATAFRAME_DATA[DATAFRAME_DATA.date != -1]

parDate = df_date.groupby(by = 'date').size().reset_index(name='count')
dates = parDate['date']
nb = parDate['count']
axes[1,1].bar(dates, nb)
axes[1,1].set_title('Nb of images by date', size = 20)


# === By category ===
parCategorie = DATAFRAME_DATA.groupby(by = 'categorie').size().reset_index(name='count')
category = parCategorie['categorie']
nb = parCategorie['count']
axes[2,0].bar(category, nb)
axes[2,0].set_title('Nb of images by category', size = 20)
plot.sca(axes[2, 0])
plot.xticks(rotation = 90)

fig.tight_layout()
fig.subplots_adjust(top=0.92)
plot.show()

# %%
print(arrondir_couleur("#b22dd6"))
